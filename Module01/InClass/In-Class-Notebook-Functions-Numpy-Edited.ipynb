# %% [markdown]
# 1. Define a function called **MakeHist** that will make a histogram and takes as its arguments a numpy array (data), integer (number of bins), and strings for its title and horizontal and vertical axis titles.
#
#
# 2. Once you have your MakeHist function defined, create a numpy array generated from the random normal distribution centered at zero.
#
# 3. Call your MakeHist function 3 times with bin values of 10, 100, and 1000. Each call should use your random numpy array as the input data. For this exersice you can select any name for the horizontal and vertical axes, but set the histogram title to the number of bins it was produced with.
#
# Expected Result (note your specific histogram numbers will differ since they are generated randomly, but the shape should be the same):

# %%
import numpy as np
import matplotlib.pyplot as plt

def MakeHist (data,num,htitle="horizontal axis",vtitle="vertical axis",title="Histogram"):
    plt.hist(data, bins=num)
    plt.xlabel(htitle)
    plt.ylabel(vtitle)
    plt.title(title)
    plt.show()

# %%
a=np.array([1,2,3,4])
MakeHist(a,7,"x","y")

# %%
array1 = np.random.normal(0, 1, 100)
print(array)
# Out:
# [ 1.02772765e+00 -1.21301530e-01  1.61870275e+00 -2.47692664e+00
#  -2.15962699e-01  1.10003022e+00  4.61105715e-02 -1.61977509e+00
#   4.43814180e-01 -1.09924260e+00 -9.20402822e-01 -4.52114064e-01
#   1.43754425e-01 -5.53634177e-01 -1.48039482e+00 -1.15536456e-01
#   9.37775892e-02  8.43860157e-01  8.88109429e-01  1.49982256e+00
#   9.15155325e-01  4.06936473e-01  7.21466868e-01 -1.51497081e+00
#  -4.75477032e-01  1.45178282e+00  3.19333388e-01  1.73947035e+00
#   6.62347902e-01 -4.51009269e-01  1.11052257e+00 -6.31488678e-01
#   2.29508280e+00 -1.85223796e-01 -9.16140393e-01  6.78552503e-01
#  -3.97553855e-01 -2.95274514e-01 -1.06324625e+00  4.76241724e-01
#  -1.07399650e+00  3.38004391e-02  1.15048815e+00 -6.30136711e-01
#  -2.45253371e-02 -1.26823552e-03 -8.37059244e-01 -2.32693675e-01
#   1.75654693e+00 -5.71110840e-01 -2.55191039e+00 -9.33499483e-01
#  -4.33437705e-02  1.46505464e-01 -1.29714007e+00 -8.70756825e-01
#   1.13891546e+00 -2.02694838e+00  1.16863250e+00 -3.05093892e-01
#  -8.84715989e-01  1.79901344e-02 -1.06781207e+00  1.14248267e+00
#   1.12483329e+00 -5.73650631e-01 -1.08889659e+00  1.41181162e+00
#  -1.15300495e+00  2.24308530e+00  7.45624998e-01  1.20307582e-01
#   2.82160960e+00  9.67900649e-01  4.94230508e-01  6.72546970e-01
#   1.02698399e+00  1.56195845e-01  9.39711400e-02  2.05262300e-01
#   6.99736290e-01  5.45220251e-02 -9.09559993e-01  9.29694822e-01
#  -7.24246957e-02  8.88807813e-01 -8.42441677e-01  1.80557881e+00
#  -7.42696452e-01 -2.35380247e+00  2.74394269e-01 -2.71268960e+00
#  -3.47699520e-01 -7.84478852e-01 -5.65363667e-01  5.22562355e-01
#   1.59777362e-01  2.50200503e-01  1.23436186e+00  1.00566948e+00]

# %%
MakeHist(array1,10,"x","y","bins=10")

# %%
MakeHist(array1,100,"x","y","bins=100")

# %%
MakeHist(array1,1000,"x","y","bins=1000")
